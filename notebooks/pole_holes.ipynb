# %%
import mask
import numpy as np
from cartoplot import cartoplot

# %%
elons = mask.get('lon')
elats = mask.get('lat')

grid_cell_area = 25_067.53**2

# %%
# ERS1

# %%
a = np.full((361,361), grid_cell_area)

a[elats<81.5] = np.nan

cartoplot(elons,elats,a)

print(np.nansum(a)/1e9)
# Out:
# 2808.2349584847216

# %%
a = np.full((361,361), grid_cell_area)

a[elats<86] = np.nan

cartoplot(elons,elats,a)

print(np.nansum(a)/1e9)

print(2808.2349584847216/621.468)
# Out:
# 621.46886863759
# 4.518712079277971

# %%
a = np.full((361,361), grid_cell_area)

a[elats<88] = np.nan

cartoplot(elons,elats,a)

print(np.nansum(a)/1e9)

print(2808.2349584847216/151.4)
# Out:
# 151.4398355325169
# 18.548447546134224

# %%
ratio_GL_IL = 2_116/103
ratio_GL_IL
# Out:
# 20.54368932038835

# %%
ratio_ERS_CS2 = 2808.23/151.4
ratio_ERS_CS2
# Out:
# 18.548414795244383
